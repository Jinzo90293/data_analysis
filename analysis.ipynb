# %%
import pandas as pd

# %%
crime_data = pd.read_csv("Crime_Data_from_2020_to_Present.csv")
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 944230  242106032  02/20/2024 12:00:00 AM  02/17/2024 12:00:00 AM      2330
# 944231  242004546  01/16/2024 12:00:00 AM  01/16/2024 12:00:00 AM      1510
# 944232  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 944233  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 944234  240900704  04/29/2024 12:00:00 AM  04/29/2024 12:00:00 AM      2020
#
#         AREA  AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          7   Wilshire          784         1     510
# 1          1    Central          182         1     330
# 2          3  Southwest          356         1     480
# 3          9   Van Nuys          964         1     343
# 4          6  Hollywood          666         2     354
# ...      ...        ...          ...       ...     ...
# 944230    21    Topanga         2103         1     420
# 944231    20    Olympic         2013         2     624
# 944232     1    Central          101         2     745
# 944233     3  Southwest          358         1     230
# 944234     9   Van Nuys          916         2     740
#
#                                               Crm Cd Desc  ... Status  \
# 0                                        VEHICLE - STOLEN  ...     AA
# 1                                   BURGLARY FROM VEHICLE  ...     IC
# 2                                           BIKE - STOLEN  ...     IC
# 3                SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC
# 4                                       THEFT OF IDENTITY  ...     IC
# ...                                                   ...  ...    ...
# 944230    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...     IC
# 944231                           BATTERY - SIMPLE ASSAULT  ...     IC
# 944232           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 944233     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 944234  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0       Adult Arrest    510.0    998.0       NaN      NaN
# 1        Invest Cont    330.0    998.0       NaN      NaN
# 2        Invest Cont    480.0      NaN       NaN      NaN
# 3        Invest Cont    343.0      NaN       NaN      NaN
# 4        Invest Cont    354.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 944230   Invest Cont    420.0      NaN       NaN      NaN
# 944231   Invest Cont    624.0      NaN       NaN      NaN
# 944232   Invest Cont    745.0      NaN       NaN      NaN
# 944233   Invest Cont    230.0      NaN       NaN      NaN
# 944234   Invest Cont    740.0    998.0       NaN      NaN
#
#                                         LOCATION  \
# 0        1900 S  LONGWOOD                     AV
# 1        1000 S  FLOWER                       ST
# 2        1400 W  37TH                         ST
# 3       14000    RIVERSIDE                    DR
# 4                              1900    TRANSIENT
# ...                                          ...
# 944230  22700    NAPA                         ST
# 944231           HOBART                       BL
# 944232   1300 W  SUNSET                       BL
# 944233           FLOWER                       ST
# 944234   6800    HAZELTINE                    AV
#
#                            Cross Street      LAT       LON
# 0                                   NaN  34.0375 -118.3506
# 1                                   NaN  34.0444 -118.2628
# 2                                   NaN  34.0210 -118.3002
# 3                                   NaN  34.1576 -118.4387
# 4                                   NaN  34.0944 -118.3277
# ...                                 ...      ...       ...
# 944230                              NaN  34.2260 -118.6214
# 944231  3RD                          ST  34.0690 -118.3054
# 944232                              NaN  34.0685 -118.2460
# 944233  JEFFERSON                    BL  34.0215 -118.2868
# 944234                              NaN  34.1939 -118.4400
#
# [944235 rows x 28 columns]

# %%
crime_data_subset = crime_data[['Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA NAME', 'Crm Cd Desc', 'Vict Age', 'Vict Sex', 'Premis Desc', 'Weapon Desc', 'Status', 'Status Desc', 'LOCATION', 'Cross Street']]

crime_data_subset.dtypes
# Out:
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA NAME          object
# Crm Cd Desc        object
# Vict Age            int64
# Vict Sex           object
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# LOCATION           object
# Cross Street       object
# dtype: object

# %%
crime_data_subset.hist(bins=50 ,figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'TIME OCC'}>,
#         <Axes: title={'center': 'Vict Age'}>],
#        [<Axes: title={'center': 'Weapon Used Cd'}>, <Axes: >]],
#       dtype=object)

# %%
vict_age_30 = crime_data_subset[crime_data_subset["Vict Age"] > 30]
vict_age_30
# Out:
#                      Date Rptd                DATE OCC  TIME OCC  AREA NAME  \
# 1       02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800    Central
# 5       04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300  Southeast
# 15      06/01/2023 12:00:00 AM  02/02/2020 12:00:00 AM       315  Southwest
# 18      11/27/2020 12:00:00 AM  11/27/2020 12:00:00 AM      1800   Wilshire
# 20      02/03/2022 12:00:00 AM  02/11/2020 12:00:00 AM      1200   Wilshire
# ...                        ...                     ...       ...        ...
# 944229  01/14/2024 12:00:00 AM  01/13/2024 12:00:00 AM       720   Foothill
# 944230  02/20/2024 12:00:00 AM  02/17/2024 12:00:00 AM      2330    Topanga
# 944231  01/16/2024 12:00:00 AM  01/16/2024 12:00:00 AM      1510    Olympic
# 944233  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500  Southwest
# 944234  04/29/2024 12:00:00 AM  04/29/2024 12:00:00 AM      2020   Van Nuys
#
#                                                      Crm Cd Desc  Vict Age  \
# 1                                          BURGLARY FROM VEHICLE        47
# 5                                              THEFT OF IDENTITY        41
# 15                                             THEFT OF IDENTITY        56
# 18                ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        31
# 20      THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD        57
# ...                                                          ...       ...
# 944229            ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        36
# 944230           THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)        44
# 944231                                  BATTERY - SIMPLE ASSAULT        80
# 944233            ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        70
# 944234   VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)        37
#
#        Vict Sex                                   Premis Desc  Weapon Used Cd  \
# 1             M             BUS STOP/LAYOVER (ALSO QUERY 124)             NaN
# 5             M                        SINGLE FAMILY DWELLING             NaN
# 15            M  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
# 18            F                                        STREET           307.0
# 20            F                        SINGLE FAMILY DWELLING             NaN
# ...         ...                                           ...             ...
# 944229        M                                        STREET           207.0
# 944230        F                                      DRIVEWAY             NaN
# 944231        F                                      BUS STOP           400.0
# 944233        F                                      SIDEWALK           308.0
# 944234        M                      VEHICLE, PASSENGER/TRUCK             NaN
#
#                                            Weapon Desc Status   Status Desc  \
# 1                                                  NaN     IC   Invest Cont
# 5                                                  NaN     IC   Invest Cont
# 15                                                 NaN     IC   Invest Cont
# 18                                             VEHICLE     AA  Adult Arrest
# 20                                                 NaN     IC   Invest Cont
# ...                                                ...    ...           ...
# 944229                                     OTHER KNIFE     IC   Invest Cont
# 944230                                             NaN     IC   Invest Cont
# 944231  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC   Invest Cont
# 944233                                           STICK     IC   Invest Cont
# 944234                                             NaN     IC   Invest Cont
#
#                                         LOCATION  \
# 1        1000 S  FLOWER                       ST
# 5        9900    COMPTON                      AV
# 15       4200    SANTO TOMAS                  DR
# 18       4500    LOMITA                       ST
# 20        800 S  TREMAINE                     AV
# ...                                          ...
# 944229   8700    LANKERSHIM                   BL
# 944230  22700    NAPA                         ST
# 944231           HOBART                       BL
# 944233           FLOWER                       ST
# 944234   6800    HAZELTINE                    AV
#
#                            Cross Street
# 1                                   NaN
# 5                                   NaN
# 15                                  NaN
# 18                                  NaN
# 20                                  NaN
# ...                                 ...
# 944229                              NaN
# 944230                              NaN
# 944231  3RD                          ST
# 944233  JEFFERSON                    BL
# 944234                              NaN
#
# [471612 rows x 14 columns]

# %%
pd.DataFrame(crime_data_subset["Crm Cd Desc"].value_counts()).plot(kind='barh', figsize=(30,30), xlabel = 'Count', title='Most Common Crimes Commited')
# Out:
# <Axes: title={'center': 'Most Common Crimes Commited'}, xlabel='Count', ylabel='Crm Cd Desc'>

# %%
crime_data_subset['AREA NAME'].value_counts()
# Out:
# AREA NAME
# Central        63732
# 77th Street    59228
# Pacific        55020
# Southwest      53464
# Hollywood      49488
# N Hollywood    47924
# Southeast      47721
# Olympic        47380
# Newton         46518
# Wilshire       45168
# Rampart        43925
# West LA        43010
# Van Nuys       40344
# Northeast      40211
# West Valley    40001
# Harbor         39098
# Devonshire     39035
# Topanga        38925
# Mission        37817
# Hollenbeck     34763
# Foothill       31463
# Name: count, dtype: int64
